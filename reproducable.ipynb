# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(); b= np.random.rand(100,2)

# %%
x = np.random.rand(100,2)
y = np.random.rand(100,2)
colors = np.random.rand(100,2)
area = np.pi * (15 * np.random.rand(100,2))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
np.mean(b, axis=0)
# Out:
# array([ 0.47640939,  0.49007202])

# %%
v = np.random.rand(50,2) + (0.47640939,  0.49007202)
t = np.random.rand(50,2) + (0.47640939,  0.49007202)
colors = np.random.rand(50,2)
area = np.pi * (15 * np.random.rand(50,2))**2

plt.scatter(v, t, s=area, c=colors, alpha=0.5)
plt.show()
